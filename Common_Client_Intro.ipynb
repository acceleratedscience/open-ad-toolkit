# %% [markdown]
# # Accelerated Discovery Common Client

# %% [markdown]
# ![](./media/AD_Banner.jpg)
# <a id="top">

# %% [markdown]
# the Accelerated Discovery Common Client is a plugin driven interface designed to consolidate differen IBM and parner API's into one common client experience across Accelerated Discovery Systems.It aims to provide a Common API and Domain Specific Language for operating with Discovery Science focused systems.

# %% [markdown]
# It currently enables access though its DSL via a command line interface and shell, and through an Jupyter Magic Command extension.

# %% [markdown]
# ### Activate Magic Commands

# %% [markdown]
# To activate Magic Commands for use in the Notebook you must run the adccl notebook.
# The first command will attempt to log the client onto the current Plugins system.

# %%
# %run adccl.ipynb

# %% [markdown]
# There are 2 Important concepts you need to understand with the client,
# 1. Workspaces: a workspace is where you can work on a distinct set of task and store all working files and logs for the related activities. Workspaces exist as a directory under ```~/.addcl/workspaces```
# 2. Contexts: Contexts are the current Plugin you are working with, they ensure you are logged onto the a plugins corresponding system and all the functionality for that system is loaded.

# %% [markdown]
# ### ***Obtaining Workspace and Context Status***

# %% [markdown]
# to get your current workspace and status simpy run ```get status```.
#
# You will notice if you have previously been logged into the system and you are calling the command from jupyter, the first command you run in that session will try to log you into the current plugin.

# %%
# %adccl get status
# Out:
# Current workspace: NEW<br>Current context: RXN<br>To see more details, run `get workspace` or `get context`.

# %% [markdown]
# ### ***Create and work with Workspaces***

# %% [markdown]
# Workspaces can be created and set as the current working directory
# A workspace is created in the ```~/.addcl/workspaces/``` Directory
# Each Workspace has it's own History file and directory to store runs an working data.
#
# Command ```CREATE WORKSPACE <workspacename> optional{ DESCRIPTION(<quoted description>) }```

# %%
# %adccl clear sessions
# Out:
# Successfully logged into Deep Search.
# Your access token expires at: 2023-06-02 00:54:35
# Are you sure? (y/n):  y
# ***Success: All other sessions have been cleared.***

# %%
# %adccl create Workspace wk6
# Out:
# Output()
# Output()
# Workspace Created however Workspace directory may already existed  WK6 , it may already exist. <br>  <br> [Errno 17] File exists: '/Users/phildowney/.adccl/workspaces/WK6'

# %%
# %adccl list toolkits
# Out:
#   Toolkit                                            Description
# 0     RXN                                Computational Chemistry
# 1   DS4SD  Deep Search: Connecting & ingesting unstructured data

# %%
# %adccl list all toolkits
# Out:
#    Toolkit Installed                                            Description
# 0    DS4SD       Yes  Deep Search: Connecting & ingesting unstructured data
# 1  RXNOLD2         -                                Computational Chemistry
# 2      RXN       Yes                                Computational Chemistry
# 3    ST4SD         -                Simulation Toolkit: Virtual Experiments
# 4   RXNOLD         -                                Computational Chemistry
# 5    GT4SD         -    Generative Toolkit: Molecular modeling & inferences

# %% [markdown]
# To List Current Workspaces simply run ```LIST WORKSPACES```

# %%
# %adccl list workspaces
# Out:
#   Workspace                             Description
# 0   DEFAULT         This is your default workspace.
# 1     * NEW  <IPython.core.display.Markdown object>

# %% [markdown]
# To remove a workspace simply run ```REMOVE WORKSPACE <workspace_name> ``` if you are currently in that workspace your current workspace will be set to ```DEFAULT```

# %%
# %adccl remove Workspace wk6
# Out:
# ***Success: Workspace successfully removed.***

# %%
# %adccl list workspaces
# Out:
#   Workspace                      Description
# 0   DEFAULT  This is your default workspace.
# 1    WALLY2
# 2       ASD
# 3     QWERT
# 4       DDD                             mine

# %% [markdown]
# ### ***Command History***

# %% [markdown]
# Th Notebooks write to the same execution history as command line executions.
# This is used to help create runs and enable paging back through history at the
# command line inteerface.

# %%
# %adccl display history
# Out:
#
# 0   11976  \
# 1   11977
# 2   11978
# 3   11979
# 4   11980
# 5   11981
# 6   11982
# 7   11983
# 8   11984
# 9   11985
# 10  11986
# 11  11987
# 12  11988
# 13  11989
# 14  11990
# 15  11991
# 16  11992
# 17  11993
# 18  11994
# 19  11995
# 20  11996
# 21  11997
# 22  11998
# 23  11999
# 24  12000
# 25  12001
# 26  12002
# 27  12003
# 28  12004
# 29  12005
# 30  12006
#
#                                                                                                                                  Command History
# 0                                                                                                                                            ...
# 1                                                                                     SEARCH FOR 'amino' USING (index_key='pubchem') SHOW (data)
# 2                                                                                                                              set context ds4sd
# 3                                                                              SEARCH FOR 'Diarylamines' USING (index_key='pubchem') SHOW (data)
# 4                                                                               SEARCH FOR 'Diarylamine' USING (index_key='pubchem') SHOW (data)
# 5                                                                                   SEARCH FOR 'caffine' USING (index_key='pubchem') SHOW (data)
# 6                                                                                   SEARCH FOR 'Caffine' USING (index_key='pubchem') SHOW (data)
# 7                                                                                                                                set context rxn
# 8                                                                     predict retrosynthesis 'CN1C=NC2=C1C(=O)N(C(=O)N2C)C' using( max_steps=8 )
# 9                                                                                                                                set context rxn
# 10                                                                                                                             set context ds4sd
# 11                                                                           SEARCH FOR ' Diethyl ether' USING (index_key='pubchem') SHOW (data)
# 12                                                                                                                               set context rxn
# 13                                                                                           predict retrosynthesis 'CCOCC' using( max_steps=8 )
# 14                                                                                                                             set context ds4sd
# 15                                                                    SEARCH FOR 'deoxyribonucleic acid' USING (index_key='pubchem') SHOW (data)
# 16                                                                         SEARCH FOR 'deoxyribonucleic' USING (index_key='pubchem') SHOW (data)
# 17                                                                              SEARCH FOR ' Sibofimloc' USING (index_key='pubchem') SHOW (data)
# 18                                                                                                                               set context rxn
# 19  predict retrosynthesis 'CC(=O)N1CCC2(CC1)C3=C(C=CC(=C3)C#CC4C(C(C(C(O4)CO)O)O)O)C5=C2C=C(C=C5)C#CC6C(C(C(C(O6)CO)O)O)O' using( max_steps=8 )
# 20                                                                                                                     create rxn project my_rxn
# 21                                                                                                                     create rxn project my_rxn
# 22                                                                        tell me the syntax for the command predict retrosynthesis with Options
# 23  predict retrosynthesis 'CC(=O)N1CCC2(CC1)C3=C(C=CC(=C3)C#CC4C(C(C(C(O4)CO)O)O)O)C5=C2C=C(C=C5)C#CC6C(C(C(C(O6)CO)O)O)O' using( max_steps=8 )
# 24  predict retrosynthesis 'CC(=O)N1CCC2(CC1)C3=C(C=CC(=C3)C#CC4C(C(C(C(O4)CO)O)O)O)C5=C2C=C(C=C5)C#CC6C(C(C(C(O6)CO)O)O)O' using( max_steps=8 )
# 25                                                                                                                                    get status
# 26                                                                                                                             list toolkits all
# 27                                                                                                                             list all toolkits
# 28                                                                                                                                 list toolkits
# 29                                                                                                                               list workspaces
# 30                                                                                                                               display history

# %% [markdown]
# ### ***Setting the Current Plugin***

# %% [markdown]
# To set the current Plugin you are operating in you use the ```Set CONTEXT <plugin_name>``` command and the plugin name. the Plugin, if this is the first time it is activated in the current session the client will try and and log onto the desitination system.
#
# In this example we will set it to the Deep Search Plugin DS4SD

# %%
# %adccl set context  DS4SD
# Out:
# ***Success: You successfully changed the plugin context to ***DS4SD***.***

# %% [markdown]
# ### ***Setting the Current Workspace*** ###
#
# To set the current workspace you runn the following command ```SET WORKSPACE <workspacename>```as you chance the workspace the history for the cursor will be loaded into the current cursor

# %%
# %adccl set workspace Default
# Out:
# You already are in the ***DEFAULT*** workspace.

# %% [markdown]
# ### ***Help***

# %% [markdown]
# Help uses the same help as the command line but uses markup language. it is accessed by using  ```?``` before any command. if there is not a unique command for the help hint given it will list all options

# %%
# %adccl ?
# Out:
# ***Available Commands*** <br> Workspaces: <br>     ```set workspace <workspace_name>``` <br>     ```create workspace <workspace_name> [ description=<workspace_description> on path '<path>' ]``` <br>     ```remove workspace <workspace_name> ``` <br>     ```list workspaces``` <br>     ```get workspace <workspace_name>``` <br>  <br> Toolkits: <br>     ```remove plugin <plugin_name>``` <br>     ```add plugin <plugin_name>``` <br>     ```list plugins``` <br>     ```list all plugins``` <br>     ```set context <plugin_name>``` <br>  <br> Runs: <br>     ```create run``` <br>     ```save run as <run_name>``` <br>     ```run <run_name>``` <br>     ```list runs``` <br>     ```display run <run_name>``` <br>  <br> File System: <br>     ```list files``` <br>     ```import from '<external_source_file>' to '<workspace_file>'``` <br>     ```export from '<workspace_file>' to '<external_file>'``` <br>     ```copy from '<workspace_file>' to '<other_workspace>'``` <br>     ```rm '<filename>'``` <br>  <br> General: <br>     ```adccl``` <br>     ```get status``` <br>     ```display history ``` <br>     ```clear sessions``` <br>  <br> Help: <br>     ```intro``` <br>     ```?``` <br>     ```??``` <br>     ```... ?``` <br>     ```docs``` <br>  <br> GUI: <br>     ```show molecules using file <mols_file> [ save as '<sdf_or_csv_file>' ]``` <br>     ```show molecules using dataframe <dataframe> [ save as '<sdf_or_csv_file>' ]``` <br>  <br> Deep Search: <br>     ```search for <quoted_string> using (index_key=<index_name> [ page_size=<int> elastic_id=<elastic_id> ]) show (data|docs) [ estimate only ]``` <br>     ```exec display_collection()``` <br>

# %%
# %adccl ? list
# Out:
# ***Commands containing "list"*** <br> ```list workspaces``` <br> ```list plugins``` <br> ```list all plugins``` <br> ```list runs``` <br> ```list files```

# %%
# %adccl ? search for
# Out:
# ```search for <quoted_string> using (index_key=<index_name> [ page_size=<int> elastic_id=<elastic_id> ]) show (data|docs) [ estimate only ]``` <br> Performs a document search of the Deep Search repository based on a given index. Use Estimate only to determine the potential number of hits.

# %% [markdown]
# ### ***Creating and Using Runs***

# %% [markdown]
# Runs are created from the command History. To create a run you first run ```create run```, this places a place holder in the command history file. You then run the commands you wish to execute in your run then issue the comand ```SAVE RUN AS <run_name>``` and the commands ran are saved to a ```*.run``` file in the workspace directory. To then execute the run you simply issue the command ```RUN <run_name>``` and the run will sequentially execute all the comands. To list what runs are available you can run ```LIST RUNS``` and to view what commands are in a run you can issue the following command ```DISPLAY RUN <run_name>```

# %%
# %adccl list Runs
# Out:
#   Stored Runs
# 0       wally
# 1      tester
# 2       test1

# %% [markdown]
# To Create a Run we simply enter Create Run, run a set of commands then entner "Save run as \<name\> "

# %%
# %adccl create run

# %%
# %adccl list runs
# Out:
#   Stored Runs
# 0       wally
# 1      tester
# 2       test1

# %%
# %adccl list plugins
# Out:
#   Plugin                                            Description
# 0  GT4SD    Generative Toolkit: Molecular modeling & inferences
# 1  ST4SD                Simulation Toolkit: Virtual Experiments
# 2  DS4SD  Deep Search: Connecting & ingesting unstructured data

# %% [markdown]
# ### Listing a Workspace

# %%
# %adccl list workspaces
# Out:
#   Workspace                      Description
# 0   DEFAULT  This is your default workspace.
# 1    WALLY2
# 2       ASD
# 3     QWERT
# 4       DDD                             mine

# %%
# %adccl save run as test1

# %% [markdown]
# ### displaying a Run

# %%
# %adccl display run test1
# Out:
#           Commands
# 0        list runs
# 1     list plugins
# 2  list workspaces

# %% [markdown]
# ### Running a Run

# %%
# %adccl run test1
# Out:
#   Stored Runs
# 0       wally
# 1      tester
# 2       test1
#   Plugin                                            Description
# 0  GT4SD    Generative Toolkit: Molecular modeling & inferences
# 1  ST4SD                Simulation Toolkit: Virtual Experiments
# 2  DS4SD  Deep Search: Connecting & ingesting unstructured data
#   Workspace                      Description
# 0   DEFAULT  This is your default workspace.
# 1    WALLY2
# 2       ASD
# 3     QWERT
# 4       DDD                             mine

# %%
# %adccl get status
# Out:
# ***Current workspace***: DEFAULT <br> ***Current context***: DS4SD <br> To see more details, run ```get workspace``` or ```get context```.

# %%
x=%adccl  show molecules using file 'base_molecules.sdf' as molsobject
# Out:
# MolGridWidget(grid_id='base_molecules.sdf')

# %%
x.display()
# Out:
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
#
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             #mols2grid {
#     /* Colors */
#     --black: rgba(0,0,0,.75);
#     --black-soft: rgba(0,0,0,.35);
#     --bg: #f6f6f6;
#     --border: solid 1px rgba(0,0,0,.1);
#     --hl: #555; /* Highlight color */
#     --hl-shadow: inset 0 0 0 1px var(--hl); /* Inset 1px shadow to make border thicker */
#
#     /* Border radius */
#     --br: 3px;
#     --br-l: var(--br) 0 0 var(--br); /* Left-only */
#     --br-r: 0 var(--br) var(--br) 0; /* Right-only */
#
#     /* Text */
#     --fs: 14px; /* UI font-size */
#     --fs-cell: 12px; /* Cell font-size */
#
#     /* Layout */
#     --h: 40px; /* Height */
#
#     /*
#      * Styling */
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--fs);
# }
#
# /* Fixes */
# #mols2grid * {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
#     /* background: pink; */
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--bg) ;
#     border: var(--border);
#     height: var(--h);
#     min-width: calc(var(--h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--h);
#     line-height: var(--h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--hl);
#     box-shadow: var(--hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--h);
#     background: var(--bg);
#     border: var(--border);
#     border-radius: var(--br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;
#     appearance: none;
#     background: transparent;
#     border: none;
#     height: 100%;
#     padding: 0 13px;
#     min-width: 0;
#     max-width: 250px;
#     color: var(--black);
#     cursor: pointer;
# }
#
# /* Icon */
# #mols2grid .m2g-dropdown .m2g-icon {
#     width: 30px;
#     height: var(--h);
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     position: absolute;
#     top: 0;
#     right: 0;
#     pointer-events: none;
# }
# #mols2grid .m2g-dropdown .m2g-icon svg:not(.m2g-stroke) {
#     fill: var(--black);
# }
# #mols2grid .m2g-dropdown .m2g-icon svg.m2g-stroke {
#     stroke: var(--black);
# }
#
# /* Display */
# /* We hide the native select element because
#  * it is limited in styling. Instead, we display
#  * the selected value in a div. */
# #mols2grid .m2g-dropdown .m2g-display {
#     position: absolute;
#     left: 0;
#     right: 0;
#     top: 0;
#     bottom: 0;
#     pointer-events: none;
#     color: var(--black);
#     line-height: var(--h);
#     padding: 0 25px 0 13px;
#
#     /* Truncate dropdown text */
#     white-space: nowrap;
# 	text-overflow: ellipsis;
# 	overflow: hidden;
# }
#
# /* Focus state */
# #mols2grid .m2g-dropdown:focus-within {
#     border-color: var(--hl);
#     box-shadow: var(--hl-shadow);
# }
#
#
#
# /**
#  * Action dropdown
#  */
#
# #mols2grid .m2g-dropdown.m2g-actions {
#     width: var(--h);
#     padding: 0;
# }
# #mols2grid .m2g-dropdown.m2g-actions select {
#     opacity: 0;
#     width: var(--h);
# }
# #mols2grid .m2g-dropdown.m2g-actions .m2g-icon {
#     width: var(--h);
# }
#
#
#
# /*
#  * Sort dropdown
#  */
#
# #mols2grid .m2g-dropdown.m2g-sort {
#     flex: 0 0 200px;
#     width: 200px; /* Needed in addition to flex-basis for small sizes! */
#     border-radius: var(--br);
#     display: flex;
# }
#
# /* Dropdown */
# #mols2grid .m2g-dropdown.m2g-sort select {
#     flex: 1 1;
#     opacity: 0;
#     /* padding-right: 70px; Space for &quot;Sort:&quot; */
#     box-sizing: border-box;
# }
#
# /* Sort order */
# #mols2grid .m2g-dropdown.m2g-sort .m2g-order {
#     background: var(--bg) url(&#x27;data:image/svg+xm

# %%
y = x.get_selection()

# %%
display(y)
# Out:
#                        ID                    NAME    SOL           SMILES
# 1     2,4-dimethylpentane     2,4-dimethylpentane  -4.26      CC(C)CC(C)C  \
# 2               1-pentene               1-pentene  -2.68           CCCC=C
# 8  1,3,5-trimethylbenzene  1,3,5-trimethylbenzene   -3.4  c1c(C)cc(C)cc1C
#
#   SOL_classification                                          ROMol
# 1            (A) low  <rdkit.Chem.rdchem.Mol object at 0x1280c7f40>
# 2         (B) medium  <rdkit.Chem.rdchem.Mol object at 0x1280c6c00>
# 8            (A) low  <rdkit.Chem.rdchem.Mol object at 0x1280c7d10>

# %%
yy= %adccl  show molecules using dataframe y
# Out:
# MolGridWidget(grid_id='show_api_molecules_y')

# %%
display(yy)
# Out:
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
#
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             #mols2grid {
#     /* Colors */
#     --black: rgba(0,0,0,.75);
#     --black-soft: rgba(0,0,0,.35);
#     --bg: #f6f6f6;
#     --border: solid 1px rgba(0,0,0,.1);
#     --hl: #555; /* Highlight color */
#     --hl-shadow: inset 0 0 0 1px var(--hl); /* Inset 1px shadow to make border thicker */
#
#     /* Border radius */
#     --br: 3px;
#     --br-l: var(--br) 0 0 var(--br); /* Left-only */
#     --br-r: 0 var(--br) var(--br) 0; /* Right-only */
#
#     /* Text */
#     --fs: 14px; /* UI font-size */
#     --fs-cell: 12px; /* Cell font-size */
#
#     /* Layout */
#     --h: 40px; /* Height */
#
#     /*
#      * Styling */
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--fs);
# }
#
# /* Fixes */
# #mols2grid * {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
#     /* background: pink; */
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--bg) ;
#     border: var(--border);
#     height: var(--h);
#     min-width: calc(var(--h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--h);
#     line-height: var(--h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--hl);
#     box-shadow: var(--hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--h);
#     background: var(--bg);
#     border: var(--border);
#     border-radius: var(--br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;
#     appearance: none;
#     background: transparent;
#     border: none;
#     height: 100%;
#     padding: 0 13px;
#     min-width: 0;
#     max-width: 250px;
#     color: var(--black);
#     cursor: pointer;
# }
#
# /* Icon */
# #mols2grid .m2g-dropdown .m2g-icon {
#     width: 30px;
#     height: var(--h);
#     display: flex;
#     align-items: center;
#     justify-content: center;
#     position: absolute;
#     top: 0;
#     right: 0;
#     pointer-events: none;
# }
# #mols2grid .m2g-dropdown .m2g-icon svg:not(.m2g-stroke) {
#     fill: var(--black);
# }
# #mols2grid .m2g-dropdown .m2g-icon svg.m2g-stroke {
#     stroke: var(--black);
# }
#
# /* Display */
# /* We hide the native select element because
#  * it is limited in styling. Instead, we display
#  * the selected value in a div. */
# #mols2grid .m2g-dropdown .m2g-display {
#     position: absolute;
#     left: 0;
#     right: 0;
#     top: 0;
#     bottom: 0;
#     pointer-events: none;
#     color: var(--black);
#     line-height: var(--h);
#     padding: 0 25px 0 13px;
#
#     /* Truncate dropdown text */
#     white-space: nowrap;
# 	text-overflow: ellipsis;
# 	overflow: hidden;
# }
#
# /* Focus state */
# #mols2grid .m2g-dropdown:focus-within {
#     border-color: var(--hl);
#     box-shadow: var(--hl-shadow);
# }
#
#
#
# /**
#  * Action dropdown
#  */
#
# #mols2grid .m2g-dropdown.m2g-actions {
#     width: var(--h);
#     padding: 0;
# }
# #mols2grid .m2g-dropdown.m2g-actions select {
#     opacity: 0;
#     width: var(--h);
# }
# #mols2grid .m2g-dropdown.m2g-actions .m2g-icon {
#     width: var(--h);
# }
#
#
#
# /*
#  * Sort dropdown
#  */
#
# #mols2grid .m2g-dropdown.m2g-sort {
#     flex: 0 0 200px;
#     width: 200px; /* Needed in addition to flex-basis for small sizes! */
#     border-radius: var(--br);
#     display: flex;
# }
#
# /* Dropdown */
# #mols2grid .m2g-dropdown.m2g-sort select {
#     flex: 1 1;
#     opacity: 0;
#     /* padding-right: 70px; Space for &quot;Sort:&quot; */
#     box-sizing: border-box;
# }
#
# /* Sort order */
# #mols2grid .m2g-dropdown.m2g-sort .m2g-order {
#     background: var(--bg) url(&#x27;data:image/svg+xm
