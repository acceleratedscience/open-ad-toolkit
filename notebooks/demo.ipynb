# %%
# %run adccl.ipynb

# %%
# %adccl list workspaces
# Out:
# Access token expires at: 2023-04-28 13:51:52
#    Workspace Description
# 0      WALLY        None
# 1  DSEXAMPLE        None

# %%
# %adccl set context  gt4sd
# Out:
# loggedin

# %%
# %adccl exec display_collection( domain="Materials Science" )
# Out:
#                                 Name      Type  Num entries        Date
# 0                            BioRxiv  Document       303393  2023-02-14  \
# 1                             Brenda    Record         7123  2023-01-03
# 2                             ChEMBL    Record      2105464  2023-01-03
# 3                           ChemRxiv  Document         8972  2023-01-03
# 4                                COD    Record       496137  2023-02-23
# 5               DeepSearch materials    Record       360536  2023-01-03
# 6                Material Components  Document        16319  2023-01-30
# 7                           NMRShift    Record        44334  2023-01-03
# 8                             PatCID    Record     37819855  2023-04-14
# 9                            PubChem    Record    113963001  2023-02-24
# 10                            RxNorm    Record       374176  2023-01-03
# 11                 SMILES from USPTO    Record    116478767  2022-12-25
# ...

# %%
# %adccl search for "Ibuprofen" using index_key=pubchem
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#     cid chemical_name                         SMILES  ec_number
# 0  3672     Ibuprofen  CC(C)CC1=CC=C(C=C1)C(C)C(=O)O  239-784-6  \
#
#                     cas_number  molecular weight
# 0  79261-49-7 (potassium salt)            206.28

# %%
# %adccl ? create Workspace
# Out:
# <h3>Accelerated Discovery Common Client Help</h3><br> <b>Command: create workspace <workspace name> description(" <user description of workspace>")</b><br> <b>Description: </b><br> This command creates a workspace optionally with a description.
# Workspaces have a directory created for all their files under the
# client directory in the users home directory($HOME/.addcl). Here all
# run files, logs and workspace artifacts are stored and accessed.

# %%
# %adccl list plugins
# Out:
#   Plugin                       Description
# 0  DS4SD          Deep Search DS4SD 2023\n
# 1  GT4SD  Generative Tool Kit GT4SD 2023\n

# %%
# %adccl show molecules using file base_molecules
# Out:
# MolGridWidget()
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
# height="200"
#
#
# allow="clipboard-write"
#
#
# sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
# srcdoc="&lt;html&gt;
#   &lt;meta charset=&quot;utf-8&quot;&gt;
#   &lt;head&gt;
#     &lt;style&gt;
#     #mols2grid.gridcontainer {
#     display: block;
#     padding-left: 1em;
#     max-width: 820px;
#     width: 820px;
# }
# #mols2grid .cell {
#     border: 1px solid #cccccc;
#     text-align: center;
#     vertical-align: top;
#     max-width: 160px;
#     width: 160px;
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: 12pt;
#     padding: 0;
#     margin: 0px;
#     float: left;
# }
# #mols2grid .cell:hover {
#     background-color: #e7e7e7 !important;
# }
# #mols2grid .cell .data-img {
#     padding: 0;
#     margin: 0;
# }
# #mols2grid .cell img, #mols2grid .cell svg {
#     max-width: 100%;
#     height: auto;
#     padding: 0;
# }
# ...

# %%
# %adccl list runs
# Out:
#      Runs
# 0      xx
# 1  wally1
# 2  athens
# 3     xxx
# 4    dean

# %%
 # %adccl list workspaces
# Out:
#    Workspace Description
# 0      WALLY        None
# 1  DSEXAMPLE        None

# %%
# %adccl display run wally1
# Out:
#               Commands
# 0        list projects
# 1     exec inference()
# 2        list projects
# 3                 exit
# 4  save  run as wally1
