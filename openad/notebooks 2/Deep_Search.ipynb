# %% [markdown]
# # Deep Search and the Common Client

# %% [markdown]
# ![](./media/AD_Banner.jpg)
# <a id="top">

# %% [markdown]
# ## You only need to run the Magic command %run if you did not execute init_magic from the command line

# %%
# %run openad_magic.ipynb #Not required if you have run init_magic

# %% [markdown]
# ## If you setup the Tell Me Large Language Model interface the below will run for you

# %% [markdown]
# The below will only run if you have a large language model account. Currently only OPENAI supported.

# %%
# %openad tell me how would I create a workspace then search for ibuprofen using deepsearch  then display them with a viewer
# Out:
# <span style="color: #ffa500">No Stored LLM Credentials for LLM Service OPENAI:<br>
#  please enter your API key</span><br>
# api_key:  ········
# <span style="color: #ffa500">Updating Embeddings for current Toolkits and Workspaces</span><br>
# <span style="color: #d00">Error in creating vector database Incorrect API key provided: w. You can find your API key at https://platform.openai.com/account/api-keys.</span><br>
# <span style="color: #d00">Problem Connecting to LLM: the vector db False was not able to be loaded</span><br>

# %% [markdown]
# Let's now remove the Deep Search Toolkit and re-add it to make sure we have the latest version.

# %%
# %openad remove toolkit DS4SD
# Out:
# <span style="color: #0d0">Logged into DS4SD as </span>phil.downey1@ibm.com<br>
# Workspace: DEFAULT<br>
# <span style="color: #0d0">The <span style="color: #dc0">DS4SD</span> toolkit was removed</span><br>

# %% [markdown]
# Let's check to make sure it is removed.

# %%
# %openad get status
# Out:
# <span style="color: #dc0">Current workspace</span>: DEFAULT<br>
# <span style="color: #dc0">Current context</span>: None<br>
# <span style="color: #ccc">To see more details, run `get workspace` or `get context`.</span><br>

# %% [markdown]
# Now let's in batch add the DS4SD Deep Search Toolkit, set it to the current context and call get status to check what workspace we are in, and that the toolkit is set.

# %%
# %openad add toolkit DS4SD
# %openad set context ds4sd
# %openad get status
# Out:
# <span style="color: #0d0">The <span style="color: #dc0">DS4SD</span> toolkit was successfully installed</span><br>
# <span style="color: #ccc">To activate this toolkit, run `set context ds4sd`</span><br>
# <span style="color: #ccc">To see what you can do, run `ds4sd ?`</span><br>
# <span style="color: #0d0">You successfully logged in to <span style="color: #dc0">DS4SD</span></span><br>
# <span style="color: #ccc">Your access token expires on Thu Jan 11, 2024  at 05:47</span><br>
# <span style="color: #dc0">Current workspace</span>: DEFAULT<br>
# <span style="color: #dc0">Current context</span>: DS4SD<br>
# <span style="color: #ccc">To see more details, run `get workspace` or `get context`.</span><br>

# %% [markdown]
# ## What Deep Search Commands Exist ?

# %% [markdown]
# Now we will list all commands are available for the Deep Search Toolkit (DS4SD)

# %%
# %openad ?  DS4SD
# Out:
# ## Available Commands - DS4SD
#
# Search Molecules:<br>
# `search for similar molecules to '<smiles>' [ save as '<filename.csv>' ]`<br>
# `search for molecules in patents from list ['<patent1>', '<patent2>', ...] | dataframe <dataframe_name> | file '<filename.csv>' [ save as '<filename.csv>' ]`<br>
# `search for patents containing molecule '<smiles>' | '<inchi>' | '<inchi_key>' [ save as '<filename.csv>' ]`<br>
# `search for substructure instances of '<smiles>' [ save as '<filename.csv>' ]`<br>
#
# Search Collections:<br>
# `search collection '<collection_name_or_key>' for '<search_string>' [ using (page_size=<int> system_id=<system_id> edit_distance=<integer> display_first=<integer>) ] show (data | docs) [ estimate only | return as data | save as '<filename.csv>' ]`<br>
# `display collection matches for '<search_string>' [ save as '<filename.csv>' ]`<br>
#
# Collections:<br>
# `display collections in domains from list <list_of_domains> [ save as '<filename.csv>' ] `<br>
# `display all collections [ save as '<filename.csv>' ]`<br>
# `display collections for domain '<domain_name>' `<br>
# `display collection details '<collection_name_or_key>'`<br>
#
#  i  <span style="color: #ccc">To learn more about the DS4SD toolkit, run `ds4sd`.</span><br>

# %% [markdown]
# ## Displaying Domains

# %% [markdown]
# ### Displaying all Collections and Domains

# %% [markdown]
# You can display all collections with the following command
# `DISPLAY ALL COLLECTIONS [SAVE AS '<csv_file_name>']`

# %%
# %openad display all collections
# Out:
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
#                                                Domains
# 0                                Scientific Literature  \
# 1                                    Business Insights
# 2                                Scientific Literature
# 3                           Healthcare & Life Sciences
# 4   Healthcare & Life Sciences / Scientific Literature
# 5                                Scientific Literature
# 6                                    Business Insights
# 7                                    Business Insights
# 8                             Climate & Sustainability
# 9                                    Materials Science
# 10                               Scientific Literature
# 11                               Scientific Literature
# 12                                   Materials Science
# 13                          Healthcare & Life Sciences
# 14                                   Business Insights
# 15                               Scientific Literature
#
#                     Collection Name    Collection Key      Type  Num Entries
# 0                     ACL Anthology               acl  Document        55278  \
# 1                    Annual Reports     annual-report  Document        79787
# 2                   arXiv abstracts    arxiv-abstract  Document      2346838
# 3                    ClinicalTrials   clinical-trials  Document       426424
# 4                            Cord19            cord19  Document       655447
# 5                          Crossref          crossref  Document    131857641
# 6                       ESG Reports        esg-report  Document        10932
# 7                      IBM Redbooks      ibm-redbooks  Document         2751
# 8                              IPCC              ipcc  Document          819
# 9                            PatCID            patcid    Record     50831401
# 10                    Patent SMILES     patent-smiles  Document      2836952
# 11               Patents from USPTO      patent-uspto  Document     15758950
# 12                          PubChem           pubchem    Record    118240842
# 13                   PubMed Central            pubmed  Document      5084756
# 14                          Red Hat            redhat  Document         6213
# 15  Semantic Scholar Academic Graph  semantic-scholar  Document    212110410
#
#           Date   System
# 0   2023-10-05  default
# 1   2023-07-21  default
# 2   2023-10-24  default
# 3   2023-06-01  default
# 4   2023-04-14  default
# 5   2023-04-15  default
# 6   2023-10-03  default
# 7   2023-08-02  default
# 8   2023-06-15  default
# 9   2023-09-05  default
# 10  2023-10-06  default
# 11  2023-09-07  default
# 12  2023-10-06  default
# 13  2023-04-12  default
# 14  2023-07-14  default
# 15  2023-05-28  default

# %% [markdown]
# ### Let's find out what Collections contain what documents we might be interested in.

# %% [markdown]
# Display collection matches searches all collections for documents that contain a given search string.<BR><br>
# `DISPLAY COLLECTION MATCHES FOR '<search_string>' [SAVE AS '<csv_file_name>']`

# %%
# %openad display collection matches for 'carbon capture'
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# <span style="color: #d00">There was an error calling DeepSearch</span><br>
# <span style="color: #ccc">Task '0_ElasticQuery' failed with 'RuntimeError': Failed to query Elasticsearch service: 500 '{"error":{"root_cause":[{"type":"too_many_nested_clauses","reason":"too_many_nested_clauses: Query contains too many nested clauses; maxClauseCount is set to 1024"}],"type":"search_phase_execution_exception","reason":"all shards failed","phase":"query","grouped":true,"failed_shards":[{"shard":0,"index":"clinical-trials-20220815","node":"q3hN1RZ_T5-3a3Gyz62CHQ","reason":{"type":"too_many_nested_clauses","reason":"too_many_nested_clauses: Query contains too many nested clauses; maxClauseCount is set to 1024"}}]},"status":500}'. Full error:<br>
# - Error Type: 'RuntimeError'<br>
# - Task ID: '0_ElasticQuery'</span><br>

# %% [markdown]
# Display collections for a specific Domain Name.<BR><br>
# `DISPLAY COLLECTIONS FOR  DOMAIN `<domain_name>`

# %%
# %openad display collections for domain 'Business Insights'
# Out:
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
#              Name      Type  Num Entries        Date                 Coords
# 0  Annual Reports  Document        79787  2023-07-21  default/annual-report
# 1     ESG Reports  Document        10932  2023-10-03     default/esg-report
# 2    IBM Redbooks  Document         2751  2023-08-02   default/ibm-redbooks
# 3         Red Hat  Document         6213  2023-07-14         default/redhat

# %% [markdown]
# ### Subset our list by a set of Domains

# %% [markdown]
# Given a list of domain names, the below command will give a list of Collections within those domains<BR><br>
# `DISPLAY COLLECTIONS IN DOMAINS FROM LIST [<list_of_domains>] [SAVE AS '<csv_file_name>']`

# %%
# %openad display collections in domains from list [ 'Business Insights','Climate & Sustainability']
# Out:
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
#                     Domains Collection Name Collection Key      Type
# 0         Business Insights  Annual Reports  annual-report  Document  \
# 1         Business Insights     ESG Reports     esg-report  Document
# 2         Business Insights    IBM Redbooks   ibm-redbooks  Document
# 3  Climate & Sustainability            IPCC           ipcc  Document
# 4         Business Insights         Red Hat         redhat  Document
#
#    Num Entries        Date   System
# 0        79787  2023-07-21  default
# 1        10932  2023-10-03  default
# 2         2751  2023-08-02  default
# 3          819  2023-06-15  default
# 4         6213  2023-07-14  default

# %% [markdown]
# ### Drill into the details behing a Collection

# %% [markdown]
# To drill down on the description of a document collection, its source and date <br> <br>
# `DISPLAY COLLECTION DETAILS '<collection_name>' | '<collection_key>'`

# %%
# %openad display collection details 'ESG Reports'
# Out:
# **ESG Reports** <br>
# <span style="color: #5b0">Collection Name: </span>ESG Reports<br>
# <span style="color: #5b0">Domains: </span>Business Insights<br>
# <span style="color: #5b0">Type: </span>Document<br>
# <span style="color: #5b0">Collection Key: </span>esg-report<br>
# <span style="color: #5b0">Documents: </span>10932<br>
# <span style="color: #5b0">Created: </span>2023-10-03<br>
# <span style="color: #5b0">URL: </span><a target="_blank" href="https://www.responsibilityreports.com/">https://www.responsibilityreports.com/</a><br>
# <span style="color: #5b0">Description: </span>Responsibility reports from global companies, including sustainability reports, corporate responsibility reports, corporate social responsibility reports, and ESG reports.<br>

# %% [markdown]
# ## Searching a collection inside the Deep Search Repository

# %% [markdown]
# The Deep Search command for searching repositories uses the below syntax:

# %% [markdown]
# ### **Searching for Documents on a Subject**
#
#
#
# In this section we search for documents in the arXiv.org data collection matching the input query. For each matched document we return the title, authors as well as the link to the original document on arXix.org
#
# ***This example will demonstrate***
#
# 1. How to address a specific data collection
# 2. How to choose which component of the documents should be returned
# 3. How to iterate through the complete data collection by fetching page_size=50 results at the time

# %% [markdown]
# The searching of a Collection command provides a flexible way that can be used in its simplest form or with a variety of options to execute a search against a variety of collections allowing you simply to pull back documents with snippets that meet the search criteria or data stored within those documents. The command syntax is as follows.<br> <br>

# %% [markdown]
# To see more about the command lets run the help for it.

# %%
 
# %openad search collection  ?
# Out:
# `search collection '<collection_name_or_key>' for '<search_string>' [ using (page_size=<int> system_id=<system_id> edit_distance=<integer> display_first=<integer>) ] show (data | docs) [ estimate only | return as data | save as '<filename.csv>' ]`<br>
# <span style="color: #ccc">---------------------------------------------------------------------------</span><br>
# Performs a document search of the Deep Search repository based on a given collection. The required `using` clause specifies the collection to search. Use `estimate only` to return only the potential number of hits.<br>
#
# Parameters:<br>
# - `<collection_name_or_key>` The name or index key for a collection. Use the command `display all collections` to list available collections.<br>
# - `<search_string>` The search string for the search.<br>
#
# The `<search_string>` supports elastic search string query syntax:<br>
# - `+` Signifies AND operation.<br>
# - `|` Signifies OR operation.<br>
# - `-` Negates a single token.<br>
# - `\"` Wraps a number of tokens to signify a phrase for searching.<br>
# - `*` At the end of a term -> signifies a prefix query<br>
# - `(` & `)` Signifies precedence<br>
# - `~N` After a word -> signifies edit distance (fuzziness)<br>
# - `~N` After a phrase -> signifies slop amount<br>
#
# Options for the `using` clause:<br>
# **Note:** The `using` clause requires all enclosed parameters to be defined in the same order as listed below.<br>
# - `page_size=<integer>` Result pagination, the default is None.<br>
# - `system_id=<system_id>` System cluster id, the default is 'default'.<br>
# - `edit_distance=<integer>` (0-5) Sets the search word span criteria for key words for document searches, the default is 5. When set to 0, no snippets will be be returned.<br>
# - `display_first=<integer>` When set, the displayed result set will be truncated at the given number.<br>
#
# Clauses:<br>
# - `show (data | docs)`:<br>
#     - `data` Display structured data from within the documents.<br>
#     - `docs` Display document context and preview snippet.<br>
#     Both can be combined in a single command, e.g. `show (data docs)`<br>
# - `estimate only` Determine the potential number of hits.<br>
# - `return as data` For Notebook or API mode. Removes all styling from the Pandas DataFrame, ready for further processing.<br>
#
# Examples:<br>
# - Look for documents that contain discussions on power conversion efficiency:<br>
# `search collection 'arxiv-abstract' for 'ide(\"power conversion efficiency\" OR PCE) AND organ*' using ( edit_distance=20 system_id=default) show (docs)`<br>
#
# - Search the PubChem archive for 'Ibuprofen' and display related molecules' data:<br>
# `search collection 'pubchem' for 'Ibuprofen' show (data)`<br>
#
# - Search for patents which mention a specific smiles molecule:<br>
# `search collection 'patent-uspto' for '\"smiles#ccc(coc(=o)cs)(c(=o)c(=o)cs)c(=o)c(=o)cs\"' show (data)`<br>

# %% [markdown]
# First we will run and get an estimate of how many documents may appear in the search so we know we are pulling back a manageable amount

# %%
# %openad search collection 'arXiv abstracts' for 'ide("power conversion efficiency" OR PCE) AND organ* '  show (docs) estimate only
# Out:
# Estimated results: 75<br>

# %% [markdown]
# ### Retrieving results ###
# Now we will retrieve and view all results, if we do not use the `return as data` clause the results will be returned as ***pandas styler*** object that provides an enhanced snippet display of the data.

# %%
df_styler= %openad search collection 'arXiv abstracts'  for 'ide("power conversion efficiency" OR PCE) AND organ* ' using \
( system_id=default edit_distance=20  ) show (data docs)
# Out:
# Estimated results: 75<br>
#   0%|          | 0/2 [00:00<?, ?it/s]
# **Result distribution by year**<br>
# <style type="text/css">
# #T_39b65_row0_col0, #T_39b65_row0_col1, #T_39b65_row0_col2, #T_39b65_row0_col3, #T_39b65_row0_col4, #T_39b65_row0_col5, #T_39b65_row0_col6, #T_39b65_row0_col7, #T_39b65_row0_col8, #T_39b65_row0_col9, #T_39b65_row0_col10, #T_39b65_row0_col11, #T_39b65_row0_col12, #T_39b65_row0_col13, #T_39b65_row0_col14, #T_39b65_row0_col15 {
#   text-align: left;
# }
# </style>
# <table id="T_39b65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_39b65_level0_col0" class="col_heading level0 col0" >2008</th>
#       <th id="T_39b65_level0_col1" class="col_heading level0 col1" >2009</th>
#       <th id="T_39b65_level0_col2" class="col_heading level0 col2" >2010</th>
#       <th id="T_39b65_level0_col3" class="col_heading level0 col3" >2011</th>
#       <th id="T_39b65_level0_col4" class="col_heading level0 col4" >2012</th>
#       <th id="T_39b65_level0_col5" class="col_heading level0 col5" >2013</th>
#       <th id="T_39b65_level0_col6" class="col_heading level0 col6" >2014</th>
#       <th id="T_39b65_level0_col7" class="col_heading level0 col7" >2015</th>
#       <th id="T_39b65_level0_col8" class="col_heading level0 col8" >2016</th>
#       <th id="T_39b65_level0_col9" class="col_heading level0 col9" >2017</th>
#       <th id="T_39b65_level0_col10" class="col_heading level0 col10" >2018</th>
#       <th id="T_39b65_level0_col11" class="col_heading level0 col11" >2019</th>
#       <th id="T_39b65_level0_col12" class="col_heading level0 col12" >2020</th>
#       <th id="T_39b65_level0_col13" class="col_heading level0 col13" >2021</th>
#       <th id="T_39b65_level0_col14" class="col_heading level0 col14" >2022</th>
#       <th id="T_39b65_level0_col15" class="col_heading level0 col15" >2023</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_39b65_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_39b65_row0_col0" class="data row0 col0" >4</td>
#       <td id="T_39b65_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_39b65_row0_col2" class="data row0 col2" >4</td>
#       <td id="T_39b65_row0_col3" class="data row0 col3" >12</td>
#       <td id="T_39b65_row0_col4" class="data row0 col4" >8</td>
#       <td id="T_39b65_row0_col5" class="data row0 col5" >8</td>
#       <td id="T_39b65_row0_col6" class="data row0 col6" >4</td>
#       <td id="T_39b65_row0_col7" class="data row0 col7" >28</td>
#       <td id="T_39b65_row0_col8" class="data row0 col8" >20</td>
#       <td id="T_39b65_row0_col9" class="data row0 col9" >52</td>
#       <td id="T_39b65_row0_col10" class="data row0 col10" >28</td>
#       <td id="T_39b65_row0_col11" class="data row0 col11" >32</td>
#       <td id="T_39b65_row0_col12" class="data row0 col12" >28</td>
#       <td id="T_39b65_row0_col13" class="data row0 col13" >32</td>
#       <td id="T_39b65_row0_col14" class="data row0 col14" >20</td>
#       <td id="T_39b65_row0_col15" class="data row0 col15" >20</td>
#     </tr>
#   </tbody>
# </table>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>

# %% [markdown]
# The Styler object can be viewed straight away or assigned as a variable, to extract the raw data we would reference `df_styler.data` to return the base data in a data frame.
# make sure the cell you are referencing has scrolling enabled by setting the properties for the cell, this way you can scroll through all the data, a window rather than taking up the entire notebook.

# %%
df_styler
# Out:
# <style type="text/css">
020</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f954_level0_row0" class="row_heading level0 row0" ></th>
#       <td id="T_3f954_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_3f954_row0_col1" class="data row0 col1" >3</td>
#     </tr>
#   </tbody>
# </table>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
# <style type="text/css">
# #T_86802_row0_col0, #T_86802_row0_col1, #T_86802_row0_col2, #T_86802_row0_col3, #T_86802_row0_col4, #T_86802_row0_col5, #T_86802_row0_col6, #T_86802_row1_col0, #T_86802_row1_col1, #T_86802_row1_col2, #T_86802_row1_col3, #T_86802_row1_col4, #T_86802_row1_col5, #T_86802_row1_col6 {
#   text-align: left;
# }
# </style>
# <table id="T_86802">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_86802_level0_col0" class="col_heading level0 col0" >Title</th>
#       <th id="T_86802_level0_col1" class="col_heading level0 col1" >Authors</th>
#       <th id="T_86802_level0_col2" class="col_heading level0 col2" >Snippet</th>
#       <th id="T_86802_level0_col3" class="col_heading level0 col3" >arxivid</th>
#       <th id="T_86802_level0_col4" class="col_heading level0 col4" >doi</th>
#       <th id="T_86802_level0_col5" class="col_heading level0 col5" >Report</th>
#       <th id="T_86802_level0_col6" class="col_heading level0 col6" >Field</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_86802_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_86802_row0_col0" class="data row0 col0" >Electrolytic Conversion of Bicarbonate into CO in a Flow Cell</td>
#       <td id="T_86802_row0_col1" class="data row0 col1" >Tengfei Li,Eric W. Lees,Maxwell Goldman,Danielle A. Salvatore,David M. Weekes,Curtis P. Berlinguette</td>
#       <td id="T_86802_row0_col2" class="data row0 col2" >This process offers a means of using electrolysis to bypass the thermally-intensive step of extracting CO2 from bicarbonate solutions generated in <span style='font-weight: bold; background-color: #FFFF00'>carbon</span> <span style='font-weight: bold; background-color: #FFFF00'>capture</span> schemes.</td>
#       <td id="T_86802_row0_col3" class="data row0 col3" ><a href="https://arxiv.org/abs/1905.04580" target="_blank">https://arxiv.org/abs/1905.04580</a></td>
#       <td id="T_86802_row0_col4" class="data row0 col4" ><a href="https://doi.org/10.1016/j.joule.2019.05.021" target="_blank">https://doi.org/10.1016/j.joule.2019.05.021</a></td>
#       <td id="T_86802_row0_col5" class="data row0 col5" >1905.04580</td>
#       <td id="T_86802_row0_col6" class="data row0 col6" >main-text.text</td>
#     </tr>
#     <tr>
#       <th id="T_86802_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_86802_row1_col0" class="data row1 col0" >Carbon Capture and Separation from CO2/N2/H2O Gaseous Mixtures in
#   Bilayer Graphtriyne: A Molecular Dynamics Study</td>
#       <td id="T_86802_row1_col1" class="data row1 col1" >Noelia Faginas-Lago,Yusuf Bramastya Apriliyanto,Andrea Lombardi</td>
#       <td id="T_86802_row1_col2" class="data row1 col2" >We also observed that the bilayer graphtriyne <span style='font-weight: bold; background-color: #FFFF00'>membrane</span> has high CO2 and H2O permeances compared to N2 with permeance selectivity ranging from 4.8 to 6.5.</td>
#       <td id="T_86802_row1_col3" class="data row1 col3" ><a href="https://arxiv.org/abs/2008.01754" target="_blank">https://arxiv.org/abs/2008.01754</a></td>
#       <td id="T_86802_row1_col4" class="data row1 col4" ></td>
#       <td id="T_86802_row1_col5" class="data row1 col5" >2008.01754</td>
#       <td id="T_86802_row1_col6" class="data row1 col6" >main-text.text</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **Search _Ibuprofen_ in PubChem**
#
# In this section we search for all PubChem entries which contain the string _Ibuprofen_.
#
# In the results table we see the name of the chemical, its molecule SMILES and some properties such as the molecular weight and the solubility.

# %%
ibuprofen_df = %openad search collection 'pubchem' for 'Ibuprofen' SHOW (data) 
display(ibuprofen_df)
# Out:
# Estimated results: 9<br>
#   0%|          | 0/1 [00:00<?, ?it/s]
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
# <style type="text/css">
# #T_2a5bd_row0_col0, #T_2a5bd_row0_col1, #T_2a5bd_row0_col2, #T_2a5bd_row0_col3, #T_2a5bd_row0_col4, #T_2a5bd_row0_col5, #T_2a5bd_row0_col6, #T_2a5bd_row0_col7, #T_2a5bd_row0_col8, #T_2a5bd_row0_col9, #T_2a5bd_row0_col10, #T_2a5bd_row0_col11, #T_2a5bd_row0_col12, #T_2a5bd_row0_col13, #T_2a5bd_row0_col14, #T_2a5bd_row0_col15, #T_2a5bd_row0_col16, #T_2a5bd_row0_col17, #T_2a5bd_row0_col18, #T_2a5bd_row0_col19, #T_2a5bd_row0_col20, #T_2a5bd_row1_col0, #T_2a5bd_row1_col1, #T_2a5bd_row1_col2, #T_2a5bd_row1_col3, #T_2a5bd_row1_col4, #T_2a5bd_row1_col5, #T_2a5bd_row1_col6, #T_2a5bd_row1_col7, #T_2a5bd_row1_col8, #T_2a5bd_row1_col9, #T_2a5bd_row1_col10, #T_2a5bd_row1_col11, #T_2a5bd_row1_col12, #T_2a5bd_row1_col13, #T_2a5bd_row1_col14, #T_2a5bd_row1_col15, #T_2a5bd_row1_col16, #T_2a5bd_row1_col17, #T_2a5bd_row1_col18, #T_2a5bd_row1_col19, #T_2a5bd_row1_col20, #T_2a5bd_row2_col0, #T_2a5bd_row2_col1, #T_2a5bd_row2_col2, #T_2a5bd_row2_col3, #T_2a5bd_row2_col4, #T_2a5bd_row2_col5, #T_2a5bd_row2_col6, #T_2a5bd_row2_col7, #T_2a5bd_row2_col8, #T_2a5bd_row2_col9, #T_2a5bd_row2_col10, #T_2a5bd_row2_col11, #T_2a5bd_row2_col12, #T_2a5bd_row2_col13, #T_2a5bd_row2_col14, #T_2a5bd_row2_col15, #T_2a5bd_row2_col16, #T_2a5bd_row2_col17, #T_2a5bd_row2_col18, #T_2a5bd_row2_col19, #T_2a5bd_row2_col20, #T_2a5bd_row3_col0, #T_2a5bd_row3_col1, #T_2a5bd_row3_col2, #T_2a5bd_row3_col3, #T_2a5bd_row3_col4, #T_2a5bd_row3_col5, #T_2a5bd_row3_col6, #T_2a5bd_row3_col7, #T_2a5bd_row3_col8, #T_2a5bd_row3_col9, #T_2a5bd_row3_col10, #T_2a5bd_row3_col11, #T_2a5bd_row3_col12, #T_2a5bd_row3_col13, #T_2a5bd_row3_col14, #T_2a5bd_row3_col15, #T_2a5bd_row3_col16, #T_2a5bd_row3_col17, #T_2a5bd_row3_col18, #T_2a5bd_row3_col19, #T_2a5bd_row3_col20, #T_2a5bd_row4_col0, #T_2a5bd_row4_col1, #T_2a5bd_row4_col2, #T_2a5bd_row4_col3, #T_2a5bd_row4_col4, #T_2a5bd_row4_col5, #T_2a5bd_row4_col6, #T_2a5bd_row4_col7, #T_2a5bd_row4_col8, #T_2a5bd_row4_col9, #T_2a5bd_row4_col10, #
d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a5bd_level0_col0" class="col_heading level0 col0" >cid</th>
#       <th id="T_2a5bd_level0_col1" class="col_heading level0 col1" >cas_number</th>
#       <th id="T_2a5bd_level0_col2" class="col_heading level0 col2" >ec_number</th>
#       <th id="T_2a5bd_level0_col3" class="col_heading level0 col3" >SMILES</th>
#       <th id="T_2a5bd_level0_col4" class="col_heading level0 col4" >chemical_name</th>
#       <th id="T_2a5bd_level0_col5" class="col_heading level0 col5" >molecular weight</th>
#       <th id="T_2a5bd_level0_col6" class="col_heading level0 col6" >xlogp3</th>
#       <th id="T_2a5bd_level0_col7" class="col_heading level0 col7" >hydrogen bond donor count</th>
#       <th id="T_2a5bd_level0_col8" class="col_heading level0 col8" >hydrogen bond acceptor count</th>
#       <th id="T_2a5bd_level0_col9" class="col_heading level0 col9" >rotatable bond count</th>
#       <th id="T_2a5bd_level0_col10" class="col_heading level0 col10" >exact mass</th>
#       <th id="T_2a5bd_level0_col11" class="col_heading level0 col11" >monoisotopic mass</th>
#       <th id="T_2a5bd_level0_col12" class="col_heading level0 col12" >topological polar surface area</th>
#       <th id="T_2a5bd_level0_col13" class="col_heading level0 col13" >heavy atom count</th>
#       <th id="T_2a5bd_level0_col14" class="col_heading level0 col14" >formal charge</th>
#       <th id="T_2a5bd_level0_col15" class="col_heading level0 col15" >complexity</th>
#       <th id="T_2a5bd_level0_col16" class="col_heading level0 col16" >isotope atom count</th>
#       <th id="T_2a5bd_level0_col17" class="col_heading level0 col17" >defined atom stereocenter count</th>
#       <th id="T_2a5bd_level0_col18" class="col_heading level0 col18" >undefined atom stereocenter count</th>
#       <th id="T_2a5bd_level0_col19" class="col_heading level0 col19" >covalently-bonded unit count</th>
#       <th id="T_2a5bd_level0_col20" class="col_heading level0 col20" >compound is canonicalized</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a5bd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2a5bd_row0_col0" class="data row0 col0" >114864</td>
#       <td id="T_2a5bd_row0_col1" class="data row0 col1" >51146-57-7</td>
#       <td id="T_2a5bd_row0_col2" class="data row0 col2" >610-621-4</td>
#       <td id="T_2a5bd_row0_col3" class="data row0 col3" >CC(C)CC1=CC=C(C=C1)C(C)C(=O)O</td>
#       <td id="T_2a5bd_row0_col4" class="data row0 col4" >(-)-ibuprofen</td>
#       <td id="T_2a5bd_row0_col5" class="data row0 col5" >206.280000</td>
#       <td id="T_2a5bd_row0_col6" class="data row0 col6" >3.500000</td>
#       <td id="T_2a5bd_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_2a5bd_row0_col8" class="data row0 col8" >2.000000</td>
#       <td id="T_2a5bd_row0_col9" class="data row0 col9" >4.000000</td>
#       <td id="T_2a5bd_row0_col10" class="data row0 col10" >206.130680</td>
#       <td id="T_2a5bd_row0_col11" class="data row0 col11" >206.130680</td>
#       <td id="T_2a5bd_row0_col12" class="data row0 col12" >37.300000</td>
#       <td id="T_2a5bd_row0_col13" class="data row0 col13" >15.000000</td>
#       <td id="T_2a5bd_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_2a5bd_row0_col15" class="data row0 col15" >203.000000</td>
#       <td id="T_2a5bd_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_2a5bd_row0_col17" class="data row0 col17" >1.000000</td>
#       <td id="T_2a5bd_row0_col18" class="data row0 col18" >0.000000</td>
#       <td id="T_2a5bd_row0_col19" class="data row0 col19" >1.000000</td>
#       <td id="T_2a5bd_row0_col20" class="data row0 col20" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_2a5bd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2a5bd_row1_col0" class="data row1 col0" >175781</td>
#       <td id="T_2a5bd_row1_col1" class="data row1 col1" >98207-12-6</td>
#       <td id="T_2a5bd_row1_col2" class="data row1 col2" ></td>
#       <td id="T_2a5bd_row1_col3" class="data row1 col3" >CC(C)CC1=CC=C(C=C1)C(C

# %% [markdown]
# ### Working with the results as Data ###
# By using the `return as data` clause we will return the data as a raw data frame, this way we will be able to pass it to other utilities.

# %%
# %openad search collection 'pubchem' for   'Ibuprofen'  SHOW (data)
# Out:
# Estimated results: 9<br>
#   0%|          | 0/1 [00:00<?, ?it/s]
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
# <style type="text/css">
# #T_cb583_row0_col0, #T_cb583_row0_col1, #T_cb583_row0_col2, #T_cb583_row0_col3, #T_cb583_row0_col4, #T_cb583_row0_col5, #T_cb583_row0_col6, #T_cb583_row0_col7, #T_cb583_row0_col8, #T_cb583_row0_col9, #T_cb583_row0_col10, #T_cb583_row0_col11, #T_cb583_row0_col12, #T_cb583_row0_col13, #T_cb583_row0_col14, #T_cb583_row0_col15, #T_cb583_row0_col16, #T_cb583_row0_col17, #T_cb583_row0_col18, #T_cb583_row0_col19, #T_cb583_row0_col20, #T_cb583_row1_col0, #T_cb583_row1_col1, #T_cb583_row1_col2, #T_cb583_row1_col3, #T_cb583_row1_col4, #T_cb583_row1_col5, #T_cb583_row1_col6, #T_cb583_row1_col7, #T_cb583_row1_col8, #T_cb583_row1_col9, #T_cb583_row1_col10, #T_cb583_row1_col11, #T_cb583_row1_col12, #T_cb583_row1_col13, #T_cb583_row1_col14, #T_cb583_row1_col15, #T_cb583_row1_col16, #T_cb583_row1_col17, #T_cb583_row1_col18, #T_cb583_row1_col19, #T_cb583_row1_col20, #T_cb583_row2_col0, #T_cb583_row2_col1, #T_cb583_row2_col2, #T_cb583_row2_col3, #T_cb583_row2_col4, #T_cb583_row2_col5, #T_cb583_row2_col6, #T_cb583_row2_col7, #T_cb583_row2_col8, #T_cb583_row2_col9, #T_cb583_row2_col10, #T_cb583_row2_col11, #T_cb583_row2_col12, #T_cb583_row2_col13, #T_cb583_row2_col14, #T_cb583_row2_col15, #T_cb583_row2_col16, #T_cb583_row2_col17, #T_cb583_row2_col18, #T_cb583_row2_col19, #T_cb583_row2_col20, #T_cb583_row3_col0, #T_cb583_row3_col1, #T_cb583_row3_col2, #T_cb583_row3_col3, #T_cb583_row3_col4, #T_cb583_row3_col5, #T_cb583_row3_col6, #T_cb583_row3_col7, #T_cb583_row3_col8, #T_cb583_row3_col9, #T_cb583_row3_col10, #T_cb583_row3_col11, #T_cb583_row3_col12, #T_cb583_row3_col13, #T_cb583_row3_col14, #T_cb583_row3_col15, #T_cb583_row3_col16, #T_cb583_row3_col17, #T_cb583_row3_col18, #T_cb583_row3_col19, #T_cb583_row3_col20, #T_cb583_row4_col0, #T_cb583_row4_col1, #T_cb583_row4_col2, #T_cb583_row4_col3, #T_cb583_row4_col4, #T_cb583_row4_col5, #T_cb583_row4_col6, #T_cb583_row4_col7, #T_cb583_row4_col8, #T_cb583_row4_col9, #T_cb583_row4_col10, #T_cb583_row4_col11, #T_cb583_row4_col12, #T_cb583_row4_col13, #T_cb583_row4_col14, #T_cb583_row4_col15, #T_cb583_row4_col16, #T_cb583_row4_col17, #T_cb583_row4_col18, #T_cb583_row4_col19, #T_cb583_row4_col20, #T_cb583_row5_col0, #T_cb583_row5_col1, #T_cb583_row5_col2, #T_cb583_row5_col3, #T_cb583_row5_col4, #T_cb583_row5_col5, #T_cb583_row5_col6, #T_cb583_row5_col7, #T_cb583_row5_col8, #T_cb583_row5_col9, #T_cb583_row5_col10, #T_cb583_row5_col11, #T_cb583_row5_col12, #T_cb583_row5_col13, #T_cb583_row5_col14, #T_cb583_row5_col15, #T_cb583_row5_col16, #T_cb583_row5_col17, #T_cb583_row5_col18, #T_cb583_row5_col19, #T_cb583_row5_col20, #T_cb583_row6_col0, #T_cb583_row6_col1, #T_cb583_row6_col2, #T_cb583_row6_col3, #T_cb583_row6_col4, #T_cb583_row6_col5, #T_cb583_row6_col6, #T_cb583_row6_col7, #T_cb583_row6_col8, #T_cb583_row6_col9, #T_cb583_row6_col10, #T_cb583_row6_col11, #T_cb583_row6_col12, #T_cb583_row6_col13, #T_cb583_row6_col14, #T_cb583_row6_col15, #T_cb583_row6_col16, #T_cb583_row6_col17, #T_cb583_row6_col18, #T_cb583_row6_col19, #T_cb583_row6_col20, #T_cb583_row7_col0, #T_cb583_row7_col1, #T_cb583_row7_col2, #T_cb583_row7_col3, #T_cb583_row7_col4, #T_cb583_row7_col5, #T_cb583_row7_col6, #T_cb583_row7_col7, #T_cb583_row7_col8, #T_cb583_row7_col9, #T_cb583_row7_col10, #T_cb583_row7_col11, #T_cb583_row7_col12, #T_cb583_row7_col13, #T_cb583_row7_col14, #T_cb583_row7_col15, #T_cb583_row7_col16, #T_cb583_row7_col17, #T_cb583_row7_col18, #T_cb583_row7_col19, #T_cb583_row7_col20, #T_cb583_row8_col0, #T_cb583_row8_col1, #T_cb583_row8_col2, #T_cb583_row8_col3, #T_cb583_row8_col4, #T_cb583_row8_col5, #T_cb583_row8_col6, #T_cb583_row8_col7, #T_cb583_row8_col8, #T_cb583_row8_col9, #T_cb583_row8_col10, #T_cb583_row8_col11, #T_cb583_row8_col12, #T_cb583_row8_col13, #T_cb583_row8_col14, #T_cb583_row8_col15, #T_cb583_row8_col16, #T_cb583_row8_col17, #T_cb583_row8_col18, #T_cb583_row8_col19, #T_cb583_row8_col20 {
#   text-align: left;
# }
# </style>
# <table id="T_cb583">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb583_level0_col0" class="col_heading level0 col0" >cid</th>
#       <th id="T_cb583_level0_col1" class="col_heading level0 col1" >cas_number</th>
#       <th id="T_cb583_level0_col2" class="col_heading level0 col2" >ec_number</th>
#       <th id="T_cb583_level0_col3" class="col_heading level0 col3" >SMILES</th>
#       <th id="T_cb583_level0_col4" class="col_heading level0 col4" >chemical_name</th>
#       <th id="T_cb583_level0_col5" class="col_heading level0 col5" >molecular weight</th>
#       <th id="T_cb583_level0_col6" class="col_heading level0 col6" >xlogp3</th>
#       <th id="T_cb583_level0_col7" class="col_heading level0 col7" >hydrogen bond donor count</th>
#       <th id="T_cb583_level0_col8" class="col_heading level0 col8" >hydrogen bond acceptor count</th>
#       <th id="T_cb583_level0_col9" class="col_heading level0 col9" >rotatable bond count</th>
#       <th id="T_cb583_level0_col10" class="col_heading level0 col10" >exact mass</th>
#       <th id="T_cb583_level0_col11" class="col_heading level0 col11" >monoisotopic mass</th>
#       <th id="T_cb583_level0_col12" class="col_heading level0 col12" >topological polar surface area</th>
#       <th id="T_cb583_level0_col13" class="col_heading level0 col13" >heavy atom count</th>
#       <th id="T_cb583_level0_col14" class="col_heading level0 col14" >formal charge</th>
#       <th id="T_cb583_level0_col15" class="col_heading level0 col15" >complexity</th>
#       <th id="T_cb583_level0_col16" class="col_heading level0 col16" >isotope atom count</th>
#       <th id="T_cb583_level0_col17" class="col_heading level0 col17" >defined atom stereocenter count</th>
#       <th id="T_cb583_level0_col18" class="col_heading level0 col18" >undefined atom stereocenter count</th>
#       <th id="T_cb583_level0_col19" class="col_heading level0 col19" >covalently-bonded unit count</th>
#       <th id="T_cb583_level0_col20" class="col_heading level0 col20" >compound is canonicalized</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb583_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb583_row0_col0" class="data row0 col0" >114864</td>
#       <td id="T_cb583_row0_col1" class="data row0 col1" >51146-57-7</td>
#       <td id="T_cb583_row0_col2" class="data row0 col2" >610-621-4</td>
#       <td id="T_cb583_row0_col3" class="data row0 col3" >CC(C)CC1=CC=C(C=C1)C(C)C(=O)O</td>
#       <td id="T_cb583_row0_col4" class="data row0 col4" >(-)-ibuprofen</td>
#       <td id="T_cb583_row0_col5" class="data row0 col5" >206.280000</td>
#       <td id="T_cb583_row0_col6" class="data row0 col6" >3.500000</td>
#       <td id="T_cb583_row0_col7" class="data row0 col7" >1.000000</td>
#       <td id="T_cb583_row0_col8" class="data row0 col8" >2.000000</td>
#       <td id="T_cb583_row0_col9" class="data row0 col9" >4.000000</td>
#       <td id="T_cb583_row0_col10" class="data row0 col10" >206.130680</td>
#       <td id="T_cb583_row0_col11" class="data row0 col11" >206.130680</td>
#       <td id="T_cb583_row0_col12" class="data row0 col12" >37.300000</td>
#       <td id="T_cb583_row0_col13" class="data row0 col13" >15.000000</td>
#       <td id="T_cb583_row0_col14" class="data row0 col14" >0.000000</td>
#       <td id="T_cb583_row0_col15" class="data row0 col15" >203.000000</td>
#       <td id="T_cb583_row0_col16" class="data row0 col16" >0.000000</td>
#       <td id="T_cb583_row0_col17" class="data row0 col17" >1.000000</td>
#       <td id="T_cb583_row0_col18" class="data row0 col18" >0.000000</td>
#       <td id="T_cb583_row0_col19" class="data row0 col19" >1.000000</td>
#       <td id="T_cb583_row0_col20" class="data row0 col20" >Yes</td>
#     </tr>
#     <tr>
#       <th id="T_cb583_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cb583_row1_col0" class="data row1 col0" >175781</td>
#       <td id="T_cb583_row1_col1" class="data row1 col1" >98207-12-6</td>
#       <td id="T_cb583_row1_col2" class="data row1 col2" ></td>
#       <td id="T_cb583_row1_col3" class="data row1 col3" >CC(C)CC1=CC=C(C=C1)C(C

# %% [markdown]
# ### Displaying the molecules in a viewer ###
# Now we will view the molecules and select to subset the molecules for further viewing.<br>
# We will do this using the show molecules command that invokes mols2grid and manages launching it for us.<br>
#
# `SHOW MOLECULES USING ( FILE '<mols_file>' | DATAFRAME <dataframe> ) [ SAVE AS '<sdf_or_csv_file>' | AS MOLSOBJECT ]`

# %%
# %openad show molecules using ?
# Out:
# `show molecules using ( file '<mols_file>' | dataframe <dataframe> ) [ save as '<sdf_or_csv_file>' | as molsobject ]`<br>
# <span style="color: #ccc">---------------------------------------------------------------------------</span><br>
# Launch the molecule viewer in your browser to examine and select molecules from a SMILES sdf/csv dataset.<br>
#
# Examples:<br>
# - `show molecules using file 'base_molecules.sdf' as molsobject`<br>
# - `show molecules using dataframe my_dataframe save as 'selection.sdf'`<br>

# %% [markdown]
# So first we will will search for molecular data records related to 'Ibuprofen' and return the data set as data to a dataframe, then pass this data fram to `show molecules` for display.

# %%
my_df= %openad search collection 'pubchem' for 'Ibuprofen' SHOW (data) return as data
# %openad show molecules using dataframe my_df
# Out:
# Estimated results: 9<br>
#   0%|          | 0/1 [00:00<?, ?it/s]
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
# MolGridWidget(grid_id='show_molecules_df_my_df')
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ## **Now We display via mols2grid object and do selections to a data frame**

# %% [markdown]
# So we will now take the same data frame and run `show molecules` but this time we will have the search return a mols2grid object so we can use the data selection capability of mols2grid within out notebook environment.

# %%
x = %openad show molecules using dataframe my_df as molsobject
# Out:
# MolGridWidget(grid_id='show_molecules_df_my_df')
# Tip: To select what parameters to display:<br>
# `result.display(**{ 'subset':['NAME'], 'tooltip':['SMILES'] })`<br>
#
# For more options, see: https://mols2grid.readthedocs.io/en/latest/notebooks/customization.html<br>

# %% [markdown]
# Now lets display the object formatting the subset display using the "name" field

# %%
x.display(**{'subset': ['NAME']})
# Out:
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# Now, select one or more tiles in the mols2grid display then run the below cell to display the selected Molecules records.

# %%
x.get_selection()
# Out:
# Empty DataFrame
# Columns: [cid, cas_number, ec_number, SMILES, NAME, molecular weight, xlogp3, hydrogen bond donor count, hydrogen bond acceptor count, rotatable bond count, exact mass, monoisotopic mass, topological polar surface area, heavy atom count, formal charge, complexity, isotope atom count, defined atom stereocenter count, undefined atom stereocenter count, covalently-bonded unit count, compound is canonicalized]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# # Searching Molecules

# %% [markdown]
# ## Search for Similar Molecules

# %% [markdown]
# Now lets consider the functions that allow us to specifically search documents containing molecules for relationships between molecules, patents and other information.

# %% [markdown]
# First Look at a search that can look for molecules that have similar make up to a provided molecule in SMILES string format.<br><br>
# `SEARCH FOR SIMILAR MOLECULES '<SMILES_string>' [SAVE AS '<csv_file_name>']`

# %%
# define molecule
smiles_Molecule='CC(C)(c1ccccn1)C(CC(=O)O)Nc1nc(-c2c[nH]c3ncc(Cl)cc23)c(C#N)cc1F' 
# now substitute the variable into the %openad command
mols = %openad search for similar molecules to '{smiles_Molecule}'  
# then display the results
display(mols)
# Out:
# **We found 10 molecules similar to the provided SMILES**<br>
# CC(C)(c1ccccn1)C(CC(=O)O)Nc1nc(-c2c[nH]c3ncc(Cl)cc23)c(C#N)cc1F<br>
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=200x200>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
#                                            ROMol
# 0  <rdkit.Chem.rdchem.Mol object at 0x135a32570>  \
# 1  <rdkit.Chem.rdchem.Mol object at 0x135a30350>
# 2  <rdkit.Chem.rdchem.Mol object at 0x135a327a0>
# 3  <rdkit.Chem.rdchem.Mol object at 0x135a32810>
# 4  <rdkit.Chem.rdchem.Mol object at 0x135a32880>
# 5  <rdkit.Chem.rdchem.Mol object at 0x135a328f0>
# 6  <rdkit.Chem.rdchem.Mol object at 0x135a32960>
# 7  <rdkit.Chem.rdchem.Mol object at 0x135a329d0>
# 8  <rdkit.Chem.rdchem.Mol object at 0x135a32a40>
# 9  <rdkit.Chem.rdchem.Mol object at 0x135a32ab0>
#
#                                                                                  SMILES
# 0  CCOC(=O)CC(Nc1nc(-c2cn(S(=O)(=O)c3ccc(C)cc3)c3ncc(Cl)cc23)c(C#N)cc1F)C(C)(C)c1ccccn1  \
# 1                           C=CCC(C)(C)C(CC(=O)O)Nc1nc(-c2c[nH]c3ncc(Cl)cc23)c(C#N)cc1F
#
# 3                                             InChI=1S/C20H19ClFN5O3/c1-20(2,30-3)15(6-16(28)29)26-19-14(22)4-10(7-23)17(27-19)13-9-25-18-12(13)5-11(21)8-24-18/h4-5,8-9,15H,6H2,1-3H3,(H,24,25)(H,26,27)(H,28,29)
# 4                            InChI=1S/C24H20ClFN6O2/c1-24(2,18-5-3-4-6-28-18)19(9-20(33)34)31-23-17(26)7-13(10-27)21(32-23)16-12-30-22-15(16)8-14(25)11-29-22/h3-8,11-12,19H,9H2,1-2H3,(H,29,30)(H,31,32)(H,33,34)
# 5                                  InChI=1S/C25H20F3N5O2/c1-25(2,19-5-3-4-6-30-19)20(10-21(34)35)32-24-18(28)7-13(11-29)22(33-24)16-12-31-23-15(16)8-14(26)9-17(23)27/h3-9,12,20,31H,10H2,1-2H3,(H,32,33)(H,34,35)
# 6                              InChI=1S/C23H19ClFN5O2S/c1-23(2,18-4-3-5-33-18)17(8-19(31)32)29-22-16(25)6-12(9-26)20(30-22)15-11-28-21-14(15)7-13(24)10-27-21/h3-7,10-11,17H,8H2,1-2H3,(H,27,28)(H,29,30)(H,31,32)
# 7                               InChI=1S/C22H18ClFN6O2S/c1-22(2,21-26-3-4-33-21)16(7-17(31)32)29-20-15(24)5-11(8-25)18(30-20)14-10-28-19-13(14)6-12(23)9-27-19/h3-6,9-10,16H,7H2,1-2H3,(H,27,28)(H,29,30)(H,31,32)
# 8                            InChI=1S/C23H21ClFN7O2/c1-23(2,17-4-5-32(3)31-17)18(8-19(33)34)29-22-16(25)6-12(9-26)20(30-22)15-11-28-21-14(15)7-13(24)10-27-21/h4-7,10-11,18H,8H2,1-3H3,(H,27,28)(H,29,30)(H,33,34)
# 9                                   InChI=1S/C27H28ClFN6/c1-5-6-9-23(27(2,3)22-10-7-8-11-31-22)33-25-21(29)12-17(14-30)24(34-25)20-16-35(4)26-19(20)13-18(28)15-32-26/h7-8,10-13,15-16,23H,5-6,9H2,1-4H3,(H,33,34)

# %% [markdown]
# ## Search for Patents Containing a Specified Molecule

# %% [markdown]
# We can also search for patents that mention a specfic SMILES defined molecule using the command. <br><br> `SEARCH FOR PATENTS CONTAINING MOLECULE ['<SMILES_molecule>'| '<inchi_molecule>'] [SAVE AS '<csv_file_name>']`

# %%
# %openad search for patents ?
# Out:
# `search for patents containing molecule '<smiles>' | '<inchi>' | '<inchi_key>' [ save as '<filename.csv>' ]`<br>
# <span style="color: #ccc">---------------------------------------------------------------------------</span><br>
# Search for mentions of a specified molecules in registered patents. The queried molecule can be described as a SMILES string, InChI or InChiKey.<br>
#
# Use the `save as` clause to save the results as a csv file in your current workspace.<br>
#
# Example:<br>
# `search for patents containing molecule 'CC(C)(c1ccccn1)C(CC(=O)O)Nc1nc(-c2c[nH]c3ncc(Cl)cc23)c(C#N)cc1F'`<br>

# %%
patents = %openad search for patents containing molecule '{smiles_Molecule}'
display(patents)
# Out:
# **We found 4 patents containing the requested SMILES**<br>
# CC(C)(c1ccccn1)C(CC(=O)O)Nc1nc(-c2c[nH]c3ncc(Cl)cc23)c(C#N)cc1F<br>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
#        PATENT ID
# 0     US10526338
# 1  JP2019505518T
# 2   CN108473493B
# 3  US20190023713

# %% [markdown]
# ## Search for Molecules in a defined List of Patents

# %% [markdown]
# Now lets consider we now have a list of patents of interest, but we want to find out what molecules are additionally mentioned in these patents. We can do this using the following command.<br><br>
# `SEARCH FOR MOLECULES IN PATENTS FROM [LIST ['<patent1>', '<patent2>' .....] | DATAFRAME <dataframe_name> | FILE '<workspace_file name>'] [SAVE AS '<csv_file_name>']`

# %%
mylist = list(patents['PATENT ID'])
myframe =  %openad search for molecules in patents from list {mylist}
display(myframe)
# Out:
# **We found 20 molecules that are mentioned in the following patents:**<br>
# US10526338<br>
# JP2019505518T<br>
# CN108473493B<br>
# US20190023713<br>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
#                                             ROMol
# 0   <rdkit.Chem.rdchem.Mol object at 0x135de1e70>  \
# 1   <rdkit.Chem.rdchem.Mol object at 0x135de1d90>
# 2   <rdkit.Chem.rdchem.Mol object at 0x135de1cb0>
# 3   <rdkit.Chem.rdchem.Mol object at 0x135de1e00>
# 4   <rdkit.Chem.rdchem.Mol object at 0x135de2650>
# 5   <rdkit.Chem.rdchem.Mol object at 0x135de26c0>
# 6   <rdkit.Chem.rdchem.Mol object at 0x135de2730>
# 7   <rdkit.Chem.rdchem.Mol object at 0x135de27a0>
# 8   <rdkit.Chem.rdchem.Mol object at 0x135de2810>
# 9   <rdkit.Chem.rdchem.Mol object at 0x135de2880>
# 10  <rdkit.Chem.rdchem.Mol object at 0x135de28f0>
# 11  <rdkit.Chem.rdchem.Mol object at 0x135de2960>
# 12  <rdkit.Chem.rdchem.Mol object at 0x135de29d0>
# 13  <rdkit.Chem.rdchem.Mol object at 0x135de2a40>
# 14  <rdkit.Chem.rdchem.Mol object at 0x135de2ab0>
# 15  <rdkit.Chem.rdchem.Mol object at 0x135de2b20>
# 16  <rdkit.Chem.rdchem.Mol object at 0x135de2b90>
# 17  <rdkit.Chem.rdchem.Mol object at 0x135de2c00>
# 18  <rdkit.Chem.rdchem.Mol object at 0x135de2c70>
# 19  <rdkit.Chem.rdchem.Mol object at 0x135de2ce0>
#
#                                                                                   SMILES
# 0                                                            CCC(=O)C=C(N)C(C)(C)c1nccs1  \
# 1          CCOC(=O)CC(Nc1nc(-c2cn(S(=O)(=O)c3ccc(C)cc3)c3ncc(Cl)cc23)c(C#N)cc1F)C(C)(C)C
# 2                                                          CCOC(=O)CC(=O)C(C)(C)c1ccccn1
# 3                                                           CCOC(=O)CC(N)C(C)(C)c1ccccn1
# 4                                                   CCOC(=O)CCC(Nc1nc(Cl)ncc1F)C1(C)COC1
# 5                                                           CCOC(=O)CCC(N)C(C)(C)c1cccs1
# 6                                               CCOC(=O)CC(Nc1nc(Cl)c(C#N)cc1F)C(C)(C)OC
# 7                                               CC1(C(CC2C34C5C3C254)Nc2nc(Cl)ncc2F)COC1
# 8   CCOC(=O)CC(Nc1nc(-c2cn(S(=O)(=O)c3ccc(C)cc3)c3ncc(Cl)cc23)c(C#N)cc1F)C(C)(C)c1ccccn1
# 9                                               CCOC(=O)C=C([N+](=O)[O-])C(C)(C)c1ccccn1
# 10                                                                 CCCC(N)C(C)(C)c1cccs1
# 11                                                       C=CCC(C)(C)C(CCC)NS(=O)C(C)(C)C
# 12                                                    CCOC(=O)CC(N(O)Cc1ccccc1)C1(C)COC1
# 13                                                                     CC(C)(C#N)c1nccs1
# 14                           C=CCC(C)(C)C(CC(=O)O)Nc1nc(-c2c[nH]c3ncc(Cl)cc23)c(C#N)cc1F
#
# 12                                                                                                       InChI=1S/C16H23NO4/c1-3-21-15(18)9-14(16(2)11-20-12-16)17(19)10-13-7-5-4-6-8-13/h4-8,14,19H,3,9-12H2,1-2H3
# 13                                                                                                                                                             InChI=1S/C7H8N2S/c1-7(2,5-8)6-9-3-4-10-6/h3-4H,1-2H3
# 14                                  InChI=1S/C22H21ClFN5O2/c1-4-5-22(2,3)17(8-18(30)31)28-21-16(24)6-12(9-25)19(29-21)15-11-27-20-14(15)7-13(23)10-26-20/h4,6-7,10-11,17H,1,5,8H2,2-3H3,(H,26,27)(H,28,29)(H,30,31)
# 15                                                InChI=1S/C20H19ClFN5O2/c1-20(2,3)15(6-16(28)29)26-19-14(22)4-10(7-23)17(27-19)13-9-25-18-12(13)5-11(21)8-24-18/h4-5,8-9,15H,6H2,1-3H3,(H,24,25)(H,26,27)(H,28,29)
# 16                                                                                                                            InChI=1S/C12H19NO2S/c1-4-15-11(14)8-9(13)12(2,3)10-6-5-7-16-10/h5-7,9H,4,8,13H2,1-3H3
# 17                                                                                                                     InChI=1S/C13H18N2O4/c1-4-19-12(16)9-11(15(17)18)13(2,3)10-7-5-6-8-14-10/h5-8,11H,4,9H2,1-3H3
# 18                                             InChI=1S/C18H17ClFN5O3/c1-18(7-28-8-18)13(3-14(26)27)24-17-12(20)6-23-16(25-17)11-5-22-15-10(11)2-9(19)4-21-15/h2,4-6,13H,3,7-8H2,1H3,(H,21,22)(H,26,27)(H,23,24,25)
# 19                                                                               InChI=1S/C17H18ClFN4O2S/c1-4-25-13(24)8-12(17(2,3)16-21-5-6-26-16)22-15-11(19)7-10(9-20)14(18)23-15/h5-7,12H,4,8H2,1-3H3,(H,22,23)

# %% [markdown]
# We can also take the resulting data frame and show them in the molecules selection viewer mols2grid using the `show molecules` command

# %%
# %openad show molecules using dataframe myframe
# Out:
# Output()
# Output()
# MolGridWidget(grid_id='show_molecules_df_myframe')
# <style>
#     /* Some CSS to integrate with Jupyter more cleanly */
#     div.output_subarea {
#         /* Undo an unfortunate max-width parameter
#         that causes the output area to be too narrow
#         on smaller screens. */
#         max-width: none;
#
#         /* Align the table with the content */
#         padding: 0;
#
#         /* Let it breathe */
#         margin-top: 20px;
#     }
# </style>
#
# <iframe class="mols2grid-iframe" frameborder="0" width="100%"
#
#
#     allow="clipboard-write"
#
#
#     sandbox="allow-scripts allow-same-origin allow-downloads allow-popups allow-modals"
#
#     srcdoc="
#
#
#
# &lt;html lang=&quot;en&quot;&gt;
#     &lt;head&gt;
#         &lt;meta charset=&quot;UTF-8&quot; /&gt;
#         &lt;meta http-equiv=&quot;X-UA-Compatible&quot; content=&quot;IE=edge&quot; /&gt;
#         &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot; /&gt;
#         &lt;title&gt;Document!&lt;/title&gt;
#
#
#
#         &lt;style&gt;
#             /**
#  * General styling
#  */
# body {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
# }
# h1,h2,h3,h4 {
#     margin: 0 0 10px 0;
# }
# h1 {
#     font-size: 26px;
# }
# h2 {
#     font-size: 20px;
#     font-weight: 400;
# }
# h3 {
# 	font-size: 16px;
# }
# p {
#     margin: 0 0 10px 0;
# }
#
#
# /* Remove body margin inside iframe */
# body.m2g-inside-iframe {
#     margin: 0;
# }
#
# /* In-cell text */
# #mols2grid .data:not(.data-img) {
#     height: 16px;
#     line-height: 16px;
# }
# /* Text truncation */
# #mols2grid .data {
#     /* Break text into multiple lines (default for static)... */
#     word-wrap: normal;
#
#     /* ...or truncate it (default for interactive). */
#     overflow: hidden;
#     white-space: nowrap;
#     text-overflow: ellipsis;
# }
#
#
# /**
#  * Popover
#  * - - -
#  * Note: this is a bootstrap variable which is not namespaced.
#  * To avoid any contamination, we only style it when the
#  * x-placement parameter is set.
#  */
# .popover[x-placement] {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     background: white;
#     border: solid 1px rgba(0,0,0,.2);
#     font-size: 12px;
#     padding: 10px;
#     border-radius: 5px;
#     box-shadow: 0 0 20px rgba(0,0,0,.15);
#     user-select: none;
# }
# .popover[x-placement] h3 {
#     margin: 0;
# }
# .popover[x-placement] .arrow {
#     width: 10px;
#     height: 10px;
#     background: #fff;
#     border: solid 1px rgba(0,0,0,.2);
#     box-sizing: border-box;
#     position: absolute;
#     transform-origin: 5px 5px;
#     clip-path: polygon(0 0, 100% 0, 100% 100%);
# }
# .popover[x-placement=&#x27;left&#x27;] .arrow {
#     transform: rotate(45deg);
#     top: 50%;
#     right: -5px;
# }
# .popover[x-placement=&#x27;right&#x27;] .arrow {
#     transform: rotate(-135deg);
#     top: 50%;
#     left: -5px;
# }
# .popover[x-placement=&#x27;top&#x27;] .arrow {
#     transform: rotate(135deg);
#     left: 50%;
#     bottom: -5px;
# }
# .popover[x-placement=&#x27;bottom&#x27;] .arrow {
#     transform: rotate(-45deg);
#     left: 50%;
#     top: -5px;
# }
#             body {
#     /* Colors */
#     --m2g-black: rgba(0,0,0,.75);
#     --m2g-black-soft: rgba(0,0,0,.35);
#     --m2g-black-10: rgba(0,0,0,.1);
#     --m2g-bg: #f6f6f6;
#     --m2g-border: solid 1px rgba(0,0,0,0.2);
#     --m2g-hl: #555; /* Highlight color */
#     --m2g-hl-shadow: inset 0 0 0 1px var(--m2g-hl); /* Inset 1px shadow to make border thicker */
#     --m2g-blue: #0f62fe;
#     --m2g-blue-soft: rgba(15,98,254,.2);
#
#     /* Icons */
#     --m2g-icn-triangle: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;rgba(0,0,0,.75)&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-triangle-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;20&quot; fill=&quot;white&quot; height=&quot;20&quot; viewBox=&quot;0 0 20 20&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M9.5713 13.285L6.2543 7.757C6.0543 7.424 6.2953 7 6.6823 7L13.3173 7C13.7053 7 13.9463 7.424 13.7453 7.757L10.4283 13.285C10.2343 13.609 9.7653 13.609 9.5713 13.285Z&quot;/&gt;&lt;/svg&gt;&#x27;);
#     --m2g-icn-cb-white: url(&#x27;data:image/svg+xml;utf8,&lt;svg width=&quot;16&quot; height=&quot;16&quot; viewBox=&quot;0 0 16 16&quot; fill=&quot;none&quot; stroke=&quot;white&quot; stroke-width=&quot;2.5&quot; stroke-linecap=&quot;round&quot; xmlns=&quot;http://www.w3.org/2000/svg&quot;&gt;&lt;path d=&quot;M4 7.65686L7 10.6569L12.6569 5.00001&quot;/&gt;&lt;/svg&gt;&#x27;);
#
#     /* Border radius */
#     --m2g-br: 3px;
#     --m2g-br-l: var(--m2g-br) 0 0 var(--m2g-br); /* Left-only */
#     --m2g-br-r: 0 var(--m2g-br) var(--m2g-br) 0; /* Right-only */
#
#     /* Text */
#     --m2g-fs: 14px; /* UI font-size */
#     --m2g-fs-cell: 12px; /* Cell font-size */
#
#     /* Transition speeds */
#     --m2g-trans: 150ms;
#
#     /* Layout */
#     --m2g-h: 40px; /* Form element height */
# }
#
# /* Styling */
# #mols2grid {
#     font-family: &#x27;DejaVu&#x27;, sans-serif;
#     font-size: var(--m2g-fs);
# }
#
# /* Fixes */
# #mols2grid *,
# #mols2grid *::before,
# #mols2grid *::after {
#     box-sizing: border-box;
#     outline: none;
# }
#
#
#
# /**
#  * Functions section
#  */
#
# #mols2grid .m2g-functions {
#     display: flex;
# }
# #mols2grid .m2g-functions .m2g-row {
#     flex: 0;
#     display: flex;
# }
#
# /* Individual elements don&#x27;t scale */
# #mols2grid .m2g-functions .m2g-row &gt; * {
#     flex: 0 0;
#     margin-right: 10px;
# }
# #mols2grid .m2g-functions .m2g-row:last-child &gt; *:last-child {
#     margin-right: 0;
# }
#
# /* Row 1: pagination + gap + sort */
# #mols2grid .m2g-functions .m2g-row:first-child {
#     flex: 1; /* Scale */
# }
# #mols2grid .m2g-functions .m2g-gap {
#     /* The gap in between will scale, so the pagination
#     stays on the left, while the rest moves to the right */
#     flex: 1;
#     margin-right: 0;
# }
#
#
#
# /*
#  * Pagination
#  */
#
# #mols2grid ul.m2g-pagination {
#     /* Unset defaults */
#     list-style-type: none;
#     margin-block-start: 0;
#     margin-block-end: 0;
#     margin-inline-start: 0;
#     margin-inline-end: 0;
#     padding-inline-start: 0;
#
#     /* Custom */
#     display: flex;
# }
# #mols2grid ul.m2g-pagination li {
#     background: var(--m2g-bg) ;
#     border: var(--m2g-border);
#     height: var(--m2g-h);
#     min-width: calc(var(--m2g-h) + 1px);
#     position: relative;
#     user-select: none;
#
#     /* Compensate for double border */
#     margin-right: -1px;
#
#     /* Center text */
#     display: flex;
#     align-items: center;
#     justify-content: center;
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     min-width: var(--m2g-h);
# }
# #mols2grid ul.m2g-pagination li a {
#     text-decoration: none;
#     color: var(--m2g-black);
#     padding: 0 10px;
#     width: 100%;
#     height: var(--m2g-h);
#     line-height: var(--m2g-h);
#     text-align: center;
#     /* Compensate for border so there&#x27;s no gap between click areas  */
#     margin: 0 -1px;
# }
#
# /* Corner shape */
# #mols2grid ul.m2g-pagination li:first-child {
#     border-radius: var(--m2g-br-l);
# }
# #mols2grid ul.m2g-pagination li:last-child {
#     border-radius: var(--m2g-br-r);
#     margin-right: 0;
# }
#
# /* Focus state */
# #mols2grid ul.m2g-pagination li:focus-within {
#     border-color: var(--m2g-hl);
#     box-shadow: var(--m2g-hl-shadow);
#     z-index: 1;
# }
#
# /* Active state */
# #mols2grid ul.m2g-pagination li.active {
#     background: var(--m2g-hl);
#     z-index: 1;
# }
# #mols2grid ul.m2g-pagination li.active a {
#     cursor: default;
#     color: #fff;
# }
#
# /* Disabled sate */
# #mols2grid ul.m2g-pagination li.disabled a {
#     cursor: default;
#     color: rgba(0,0,0,.25);
#     pointer-events: none;
# }
#
#
#
# /*
#  * Dropdowns
#  */
#
# #mols2grid ::placeholder {
#     color: var(--m2g-black-soft);
# }
# #mols2grid .m2g-dropdown {
#     height: var(--m2g-h);
#     background: var(--m2g-bg);
#     border: var(--m2g-border);
#     border-radius: var(--m2g-br);
#     position: relative;
# }
# #mols2grid .m2g-dropdown select {
#     -webkit-appearance: none;
#     -moz-appearance: none;
#     -ms-appearance: none;

# %% [markdown]
# ## Search for Molecules with instances of a Specified Substructure

# %% [markdown]
# We can also search for molecules with substructure similarities to a given smiles string using the following command.
#
# `SEARCH FOR SUBSTRUCTURE INSTANCES OF '<SMILES_string>' [SAVE AS '<csv_file_name>']`

# %% [markdown]
# The following example searches for molecules containing a defined SMILES substructure string and saves it to a file my_mol which will be saved as a csv file 'my_mol.csv' in the current workspace.

# %%
# %openad search for substructure instances of 'C1(C(=C)C([O-])C1C)=O' save as 'my_mol'
# Out:
# <span style="color: #0d0">File successully saved to your workspace</span><br>
# **We found 10 molecules that contain the provided substructure**<br>
# C1(C(=C)C([O-])C1C)=O<br>
# <span style="color: #ccc">Next up, you can run: </span>`result open`/`edit`/`copy`/`display`/`save [as '<filename.csv>']`<br>
#                                            ROMol
# 0  <rdkit.Chem.rdchem.Mol object at 0x13619c510>  \
# 1  <rdkit.Chem.rdchem.Mol object at 0x13619c580>
# 2  <rdkit.Chem.rdchem.Mol object at 0x13619cc10>
# 3  <rdkit.Chem.rdchem.Mol object at 0x13619c660>
# 4  <rdkit.Chem.rdchem.Mol object at 0x13619cc80>
# 5  <rdkit.Chem.rdchem.Mol object at 0x13619ccf0>
# 6  <rdkit.Chem.rdchem.Mol object at 0x13619cd60>
