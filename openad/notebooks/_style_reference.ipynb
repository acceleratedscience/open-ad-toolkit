# %%
# Import styles
import sys
sys.path.append('./styles')
from init_style import init
init()
# Out:
# <style>
# @import url('https://fonts.googleapis.com/css2?family=IBM+Plex+Sans:wght@300;400;600&display=swap');
#
# body {
#     --ibm-blue: #0f62fe;
#     --dark-blue: #2756ad;
# }
#
# h1,h2,h3,h4,p {
#     font-family: "IBM Plex Sans";
#     color: rgba(0,0,0,.7) !important;
# }
# h1,h2 {
#     margin: 60px 0 10px 0 !important;
# }
# h3,h4 {
#     margin: 40px 0 10px 0 !important;
# }
# h1 {
#     font-size: 2.8em !important;
#     font-weight: 300 !important;
# }
# h2 {
#     font-size: 2.2em !important;
#     color: var(--dark-blue) !important;
# }
# h3 {
#     font-size: 1.5em !important;
#     font-weight: 600 !important;
# /*     font-style: italic !important; */
# }
# h4 {
#     font-size: 1.2em !important;
#     text-decoration: underline;
#     text-decoration-color: rgba(0,0,0,.2);
#     text-underline-offset: 2px;
# }
# h1 + h2,
# h1 + h3,
# h1 + h4,
# h2 + h3,
# h2 + h4,
# h3 + h4 {
#     margin-top: 30px !important;
# }
# p, ul, ol {
#     max-width: 800px !important;
# ...

# %% [markdown]
# <!-- Header banner -->
# <div class="banner"><div>Your Title Here</div><b>OpenAD <span>Tutorial</span></b></div>

# %% [markdown]
# _Title styles have top margin baked in:_
#
# # Main title
#
# Body text
#
# ## Subtitle
#
# Body text
#
# ### Sub-subtitle
#
# Body text
#
# #### Sub-sub-subtitle
# Body text
#
#
# <br><br>
# _The top margin is removed from a header when its preceded by a higher-level title:_
#
# # Main title
#
# ## Subtitle
#
# ### Sub-subtitle
#
# #### Sub-sub-subtitle

# %% [markdown]
# # Notebook Template

# %% [markdown]
# <!-- Source: https://gist.github.com/DanielKotik/4b81480c479a57e0dd13ac4d153e4451 -->
#
# <div class="alert alert-block alert-info"><b>NOTE</b> Use blue boxes for Tips and notes.</div>
#
# <div class="alert alert-block alert-success">Use green boxes sparingly, and only for some specific purpose that the other boxes can't cover. For example, if you have a lot of related content to link to, maybe you decide to use green boxes for related links from each section of a notebook.</div>
#
# <div class="alert alert-block alert-warning">Use yellow boxes for examples that are not inside code cells, or use for mathematical formulas if needed.</div>
#
# <div class="alert alert-block alert-danger">In general, just avoid the red boxes.</div>
